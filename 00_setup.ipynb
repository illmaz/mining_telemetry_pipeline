# %%
# %sql
CREATE SCHEMA IF NOT EXISTS mining.landing
COMMENT 'Raw sensor telemetry from haul trucks lands here; unvalidated and may contain corrupted readings'

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS mining.ground_truth
COMMENT 'Answer key walled off'

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS mining.bronze
COMMENT 'Raw telemetry as ingested'

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS mining.silver
COMMENT 'Cleaned telemetry'

# %%
# %sql
CREATE SCHEMA If NOT EXISTS mining.gold
COMMENT 'Mining IoT gold layer production_reconciliation for downstream consumption'

# %%
# %sql
CREATE VOLUME IF NOT EXISTS mining.landing.telemetry
COMMENT 'Dirty JSON files from trucks'

# %%
# %sql
CREATE VOLUME IF NOT EXISTS mining.ground_truth.truth 
COMMENT 'Per-cycle true tonnage written by the generator; answer key for validating gold the pipeline must never read from here'

# %%
# %sql
CREATE VOLUME IF NOT EXISTS mining.bronze.checkpoints
COMMENT 'Auto Loader checkpoint and schema state for bronze ingestion'
